# %% [markdown]
# <a href="https://colab.research.google.com/github/hansjang/Py_Radar/blob/main/%EB%8D%B0%EC%8B%B8%EB%9D%BC%EB%A9%B4Part4_P145_%EB%B6%84%EB%A5%98%EB%B6%84%EC%84%9D_%EC%95%84%EC%9D%B4%EB%A6%AC%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 데이터 확인
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()  # iris 로드하기
iris_dt = iris.data # iris/data는 독립변수(feature)만으로 된 numpy 형태
iris_label = iris.target # iris.target은 종속변수(label) 값을 numpy 형태로 가짐

df = pd.DataFrame(data=iris_dt, columns=iris.feature_names)
df['label'] = iris_label

display(df.head())
display(df.shape)
display(df.info())
display(df['label'].unique())
# 0 : Setosa
# 1 : Versicolor
# 2 : Virginica
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   label              150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
# array([0, 1, 2])

# %%
# 2. 데이터 분할
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(iris_dt, iris_label,
                                                    test_size = 0.2, random_state = 0,
                                                    stratify = iris_label)

# %%
# 3. 전처리 - 결측치
display(df.isna().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# label                0
# dtype: int64

# %%
# 4. 모델학습 - 의사결정나무
from sklearn.tree import DecisionTreeClassifier
dtree_clf_5 = DecisionTreeClassifier(max_depth = 5, random_state = 100)
dtree_clf_3 = DecisionTreeClassifier(max_depth = 3, random_state = 100)
dtree_clf_1 = DecisionTreeClassifier(max_depth = 1, random_state = 100)

# %%
# 4-1. 교차 검증 정확도 산출 (dtree_clf_5)
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(dtree_clf_5, x_train, y_train,
                         scoring = 'accuracy', cv = 10)
print('교차 검증 정확도 :', np.round(scores, 3))
print('평균 검증 정확도 :', np.round(np.mean(scores), 4))
# Out:
# 교차 검증 정확도 : [0.917 1.    0.917 1.    1.    0.833 1.    0.917 1.    0.833]
# 평균 검증 정확도 : 0.9417

# %%
# 4-1. 교차 검증 정확도 산출 (dtree_clf_3)
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(dtree_clf_3, x_train, y_train,
                         scoring = 'accuracy', cv = 10)
print('교차 검증 정확도 :', np.round(scores, 3))
print('평균 검증 정확도 :', np.round(np.mean(scores), 4))
# Out:
# 교차 검증 정확도 : [0.917 1.    0.917 0.917 1.    0.833 1.    0.917 0.917 0.833]
# 평균 검증 정확도 : 0.925

# %%
# 4-1. 교차 검증 정확도 산출 (dtree_clf_1)
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(dtree_clf_1, x_train, y_train,
                         scoring = 'accuracy', cv = 10)
print('교차 검증 정확도 :', np.round(scores, 3))
print('평균 검증 정확도 :', np.round(np.mean(scores), 4))
# Out:
# 교차 검증 정확도 : [0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667]
# 평균 검증 정확도 : 0.6667

# %%
# 5. 성능평가
dtree_clf_5.fit(x_train, y_train)
pred = dtree_clf_5.predict(x_test)
from sklearn.metrics import accuracy_score
print(f'의사결정나무(교차검증 후) 예측 정확도 : {np.round(accuracy_score(y_test, pred),5)}')
# Out:
# 의사결정나무(교차검증 후) 예측 정확도 : 0.96667

# %%
# 6. 예측값 저장
pred = pd.DataFrame(pred, columns=['pred Species'])
pred.head()
# Out:
#    pred Species
# 0             0
# 1             1
# 2             0
# 3             2
# 4             0

# %%
actual = pd.DataFrame(y_test, columns=['actual Species'])
actual.head()
# Out:
#    actual Species
# 0               0
# 1               1
# 2               0
# 3               2
# 4               0

# %%
classify_result = pd.concat([actual, pred], axis=1)
classify_result.to_csv('clf_result.csv', index=False, encoding='utf=8-sig')
classify_result.head()
# Out:
#    actual Species  pred Species
# 0               0             0
# 1               1             1
# 2               0             0
# 3               2             2
# 4               0             0
