# %% [markdown]
# <a href="https://colab.research.google.com/github/hansjang/Py_Radar/blob/main/finance2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas==1.5.3
# !pip install numpy
import pandas as pd
import numpy as np

# %%
data = {
    'name': ['철수', '영희', '수만', '영수'],
    'age': [15, 12, 20, 35]
}

df = pd.DataFrame(data)

# %%
doc = {
    'name': '세종',
    'age': 23
}

df = df.append(doc, ignore_index=True)
df
# Out:
# <ipython-input-21-cf0d06f79398>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(doc, ignore_index=True)
#   name  age
# 0   철수   15
# 1   영희   12
# 2   수만   20
# 3   영수   35
# 4   세종   23

# %%
df['city'] = ['서울', '부산', '대구', '서울', '울산']
df
# df[['name', 'city']]

# cond = df['age'] < 20
# df[cond]

# 마지막 줄의 첫 컬럼
# df.iloc[-1, 0]

# 가장 나이 많은 name은?
# df.sort_values(by='age', ascending = False).iloc[0, 0]
# Out:
#   name  age city is_adult
# 0   철수   15   서울      청소년
# 1   영희   12   부산      청소년
# 2   수만   20   대구       성인
# 3   영수   35   서울       성인
# 4   세종   23   울산       성인

# %%
df['is_adult'] = np.where(df['age'] < 20, '청소년', '성인')
df
# Out:
#   name  age city is_adult
# 0   철수   15   서울      청소년
# 1   영희   12   부산      청소년
# 2   수만   20   대구       성인
# 3   영수   35   서울       성인
# 4   세종   23   울산       성인

# %%
df['age'].describe()
# Out:
# count     5.000000
# mean     21.000000
# std       8.916277
# min      12.000000
# 25%      15.000000
# 50%      20.000000
# 75%      23.000000
# max      35.000000
# Name: age, dtype: float64

# %%
cond = df['city'] == '서울'
df[cond]['age'].mean()
# df[cond]['age'].max()
# Out:
# 35
